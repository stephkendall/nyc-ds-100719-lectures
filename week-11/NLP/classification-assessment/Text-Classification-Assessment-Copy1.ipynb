# %% [markdown]
# # Text Classification Assessment
#
# This assessment is a text classification project where the goal is to classify the genre of a movie based on its characteristics, primarily the text of the plot summarization. You have a training set of data that you will use to identify and create your best predicting model. Then you will use that model to predict the classes of the test set of data. We will compare the performance of your predictions to your classmates using the F1 Score. https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html
#
# The **movie_train.csv** dataset contains information (`Release Year`, `Title`, `Plot`, `Director`, `Cast`) about 10,682 movies and the label of `Genre`. There are 9 different genres in this data set, so this is a multiclass problem. You are expected to primarily use the plot column, but can use the additional columns as you see fit.
#
# After you have identified your best performing model, you will create predictions for the test set of data. The test set of data, contains 3,561 movies with all of their information except the `Genre`.
#
# Below is a list of tasks that you will definitely want to complete for this challenge, but this list is not exhaustive. It does not include any tasks around handling class imbalance or about how to test multiple different models and their tuning parameters, but you should still look at doing those to see if they help you to create a better predictive model.
#
#
# # Good Luck

# %% [markdown]
# ### Task #1: Perform imports and load the dataset into a pandas DataFrame

# %%
import numpy as np
import pandas as pd
import seaborn as sns

df = pd.read_csv('movie_train.csv')
df.head()
# Out:
#    Unnamed: 0  Release Year               Title  \
# 0       10281          1984      Silent Madness
# 1        7341          1960  Desire in the Dust
# 2       10587          1986         On the Edge
# 3       25495          1988           Ram-Avtar
# 4       16607          2013       Machete Kills
#
#                                                 Plot           Director  \
# 0  A computer error leads to the accidental relea...     Simon Nuchtern
# 1  Lonnie Wilson (Ken Scott), the son of a sharec...  Robert L. Lippert
# 2  A gaunt, bushy-bearded, 44-year-old Wes Holman...        Rob Nilsson
# 3  Ram and Avtar are both childhood best friends....    Sunil Hingorani
# 4  Machete Cortez (Danny Trejo) and Sartana River...   Robert Rodriguez
#
#                                                 Cast   Genre
# 0                Belinda Montgomery, Viveca Lindfors  horror
# 1            Raymond Burr, Martha Hyer, Joan Bennett   drama
# 2                              Bruce Dern, Pam Grier   drama
# 3                   Sunny Deol, Anil Kapoor, Sridevi   drama
# 4  Danny Trejo, Michelle Rodriguez, Sofía Vergara...  action

# %% [markdown]
# ### Task #2: Check for missing values:

# %%
# Check for NaN values:
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Release Year      0
# Title             0
# Plot              0
# Director          0
# Cast            169
# Genre             0
# dtype: int64

# %%
# Check for whitespace strings (it's OK if there aren't any!):
blanks = []  # start with an empty list

for rv in df.itertuples():  # iterate over the DataFrame
    if type(rv)==str:            # avoid NaN values
        for i in df.itertuples():
            if rv.isspace():         # test 'review' for whitespace
                blanks.append(i)     # add matching index numbers to the list
        
len(blanks)
# Out:
# 0

# %% [markdown]
# ### Task #3: Remove NaN values:

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Task #4: Take a look at the columns and do some EDA to familiarize yourself with the data.

# %%
df.head()
# Out:
#    Unnamed: 0  Release Year               Title  \
# 0       10281          1984      Silent Madness
# 1        7341          1960  Desire in the Dust
# 2       10587          1986         On the Edge
# 3       25495          1988           Ram-Avtar
# 4       16607          2013       Machete Kills
#
#                                                 Plot           Director  \
# 0  A computer error leads to the accidental relea...     Simon Nuchtern
# 1  Lonnie Wilson (Ken Scott), the son of a sharec...  Robert L. Lippert
# 2  A gaunt, bushy-bearded, 44-year-old Wes Holman...        Rob Nilsson
# 3  Ram and Avtar are both childhood best friends....    Sunil Hingorani
# 4  Machete Cortez (Danny Trejo) and Sartana River...   Robert Rodriguez
#
#                                                 Cast   Genre
# 0                Belinda Montgomery, Viveca Lindfors  horror
# 1            Raymond Burr, Martha Hyer, Joan Bennett   drama
# 2                              Bruce Dern, Pam Grier   drama
# 3                   Sunny Deol, Anil Kapoor, Sridevi   drama
# 4  Danny Trejo, Michelle Rodriguez, Sofía Vergara...  action

# %%
df['Genre'].value_counts()
# Out:
# drama        3673
# comedy       2703
# action        823
# horror        810
# thriller      680
# romance       644
# western       525
# adventure     329
# crime         326
# Name: Genre, dtype: int64

# %%
len(df)
# Out:
# 10513

# %% [markdown]
# #### Shortcut: Make an Abridged Version of DF for Sample Testing

# %%
df1 = df.sample(2500)
df1.head()
# Out:
#        Unnamed: 0  Release Year             Title  \
# 2031         6962          1958       Auntie Mame
# 2730        10038          1982    Visiting Hours
# 7250        16067          2011         Limitless
# 10112        6973          1958      The Bravados
# 8757        19378          1958  Dublin Nightmare
#
#                                                     Plot          Director  \
# 2031   Patrick Dennis (Jan Handzlik), orphaned in 192...    Morton DaCosta
# 2730   Deborah Ballin, a feminist activist, inspires ...  Jean-Claude Lord
# 7250   Eddie Morra is a struggling author with writer...       Neil Burger
# 10112  Jim Douglas (Gregory Peck) is a rancher pursui...        Henry King
# 8757   Irish nationalists plans to seize a security v...      John Pomeroy
#
#                                                     Cast     Genre
# 2031   Rosalind Russell, Coral Browne, Forrest Tucker...    comedy
# 2730                         Michael Ironside, Lee Grant  thriller
# 7250   Bradley Cooper, Abbie Cornish, Robert De Niro,...  thriller
# 10112  Gregory Peck, Stephen Boyd, Albert Salmi, Joan...   western
# 8757       William Sylvester, Marla Landi, Richard Leech     crime

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 2031 to 766
# Data columns (total 7 columns):
# Unnamed: 0      2500 non-null int64
# Release Year    2500 non-null int64
# Title           2500 non-null object
# Plot            2500 non-null object
# Director        2500 non-null object
# Cast            2500 non-null object
# Genre           2500 non-null object
# dtypes: int64(2), object(5)
# memory usage: 156.2+ KB

# %%
df1['Genre'].value_counts()
# Out:
# drama        882
# comedy       629
# action       213
# horror       197
# romance      166
# thriller     149
# western      117
# adventure     81
# crime         66
# Name: Genre, dtype: int64

# %% [markdown]
# #### Check percentage of total for each genre for each dataframe

# %%
lens = []
for x in df1['Genre'].value_counts():
    length = round((x/len(df1)),3)
    lens.append(length)
    
lens
# Out:
# [0.353, 0.252, 0.085, 0.079, 0.066, 0.06, 0.047, 0.032, 0.026]

# %%
lens1 = []
for x in df['Genre'].value_counts():
    length = round((x/len(df)),3)
    lens1.append(length)
    
lens1
# Out:
# [0.349, 0.257, 0.078, 0.077, 0.065, 0.061, 0.05, 0.031, 0.031]

# %%
df1
# Out:
#        Unnamed: 0  Release Year  \
# 2031         6962          1958
# 2730        10038          1982
# 7250        16067          2011
# 10112        6973          1958
# 8757        19378          1958
# 4591        23482          2001
# 3390        24151          2014
# 1484        15285          2007
# 4489        12705          1996
# 5718        14161          2002
# 2830        13853          2001
# 9960        28367          2013
# 4033         5660          1952
# 2509        12011          1993
# 2031               Morton DaCosta
# 2730             Jean-Claude Lord
# 7250                  Neil Burger
# 10112                  Henry King
# 8757                 John Pomeroy
# 4591                  Edward Yuen
# 3390                     Deb Bera
# 1484              Craig Gillespie
# 4489                Peter Jackson
# 5718                 Roger Kumble
# 2830                Terry Zwigoff
# 9960                     Siddique
# 4033                   Frank Ross
# 2509                  Adam Marcus
# 9776               Bradley Parker
# 3808             Jennifer Leitzes
# 5880                  Gene Wilder
# 5271                 Suseenthiran
# 6542   Alejandro Gomez Monteverde
# 1782                  Jeff Probst
# 6858              Peter Landesman
# 5195                 Roger Corman
# 7060              Martin Scorsese
# 7859                        Bijoy
# 6529                   Dulal Guha
# 9241                    Val Guest
# 5941                 Philip Dunne
# 4627                  Tyler Perry
# 10277               Samuel Fuller
# 6057              George Marshall
# ...                           ...
# 10055              Edwin L. Marin
# 7081                Nasir Hussain
# 9999              J. Lee Thompson
# 2046                Kishore Kumar
# 8140               Robert Redford
# 6631                Peng Xiaolian
# 1320                Blake Edwards
# 1899                 Pat O'Connor
# 5662      Juan Carlos Fresnadillo
# 6700              Paul Mayersberg
# 6941               Ken Weiderhorn
# 8856               Howard W. Koch
# 13                 Hassan Al Imam
# 6482           John Stalberg, Jr.
# 8577                    Bill Gunn
# 1464                  Tay Garnett
# 6547                  Scott Wiper
# 10633            D. Ross Lederman
# 7174               Fred Zinnemann
# 944                    Don Siegel
# 3859              Bruce McCulloch
# 4443                 Duniya Soori
# 2216              George Marshall
# 7232                 Alan Bridges
# 4823                      Unknown
# 4846                J. Om Prakash
# 4120                Samuel Fuller
# 10126                 Don Chaffey
# 6009              William Wellman
# 766                   Raoul Walsh
#
#                                                     Cast     Genre
# 2031   Rosalind Russell, Coral Browne, Forrest Tucker...    comedy
# 2730                         Michael Ironside, Lee Grant  thriller
# 7250   Bradley Cooper, Abbie Cornish, Robert De Niro,...  thriller
# 10112  Gregory Peck, Stephen Boyd, Albert Salmi, Joan...   western
# 8757       William Sylvester, Marla Landi, Richard Leech     crime
# 4591   Ben Wong, Iris Wong, Tommy Wong, William Ho, L...     crime
# 3390   Jeet, Abir Chatterjee, Priyanka Sarkar, Shradd...    action
# 1484   Billy Bob Thornton, Seann William Scott, Susan...    comedy
# 4489                      Michael J. Fox, Trini Alvarado    horror
# 5718      Cameron Diaz, Christina Applegate, Selma Blair    comedy
# 2830   Thora Birch, Scarlett Johansson, Brad Renfro, ...     drama
# 9960   Mohanlal, Meera Jasmine, Mamta Mohandas, Padma...    comedy
# 4033                         David Niven, Joan Caulfield    comedy
# 2509                              Kane Hodder, Erin Gray    horror
# 9776   Jesse McCartney, Jonathan Sadowski, Devin Kell...    horror
# 3808   Kyra Sedgwick, Stanley Tucci, Robin Tunney, Ro...     crime
# 5880              Gilda Radner, Gene Wilder, Dom DeLuise    comedy
# 5271   Vikram, Deeksha Seth, K. Vishwanath, Mithra Ku...     drama
# 6542    Eduardo Verástegui, Tammy Blanchard, Manny Pérez     drama
# 1782   Erik Palladino, James Earl Jones, Ryan Reynold...  thriller
# 6858   Will Smith\r\nAlbert Brooks\r\nAlec Baldwin\r\...     drama
# 5195                             Ben Vereen, Talia Shire    comedy
# 7060   Paul Newman, Tom Cruise, Mary Elizabeth Mastra...     drama
# 7859                     Jisshu Sengupta, Rudranil Ghosh    comedy
# 6529                  Dharmendra, Hema Malini, Ajit Khan    action
# 9241             William Graham, Garry Marsh, Jane Welsh    comedy
# 5941             Elvis Presley, Tuesday Weld, Hope Lange    comedy
# 4627   Tyler Perry, Kathy Najimy, Chad Michael Murray...    comedy
# 10277                          Robert Ryan, Robert Stack     drama
# 6057                         Rex Harrison, Rita Hayworth    comedy
# ...                                                  ...       ...
# 10055  Basil Rathbone, Randolph Scott, Elisabeth Bergner     drama
# 7081   Dharmendra, Zeenat Aman, Vijay Arora, Tariq Kh...     drama
# 9999   Charles Bronson, Jacqueline Bisset, John Houseman    action
# 2046   Kishore Kumar, Supriya Chowdhury, Amit Kumar, ...     drama
# 8140            Robert Redford, Meryl Streep, Tom Cruise     drama
# 6631                         Josephine Koo,\r\nJoey Wang     drama
# 1320              Dudley Moore, Ann Reinking, Amy Irving    comedy
# 1899                       Keanu Reeves, Charlize Theron   romance
# 5662   Robert Carlyle, Rose Byrne, Jeremy Renner, Idr...    horror
# 6700                            Irina Brook, Oliver Reed  thriller
# 6941                      Richard Mulligan, Kim Richards    comedy
# 8856                      Boris Karloff, Don 'Red' Barry    horror
# 13          Faten Hamama, Kamal Al-Shennawi, Hind Rostom     drama
# 6482   Adrien Brody, Sean Marquette, Matt Bush, Colin...    comedy
# 8577               Bill Gunn, Duane Jones, Marlene Clark    horror
# 1464                        Martha Scott, William Gargan     drama
# 6547   The Miz, Neal McDonough, Michael Eklund, Ashle...    action
# 10633                              Ruth Ford, John Loder     drama
# 7174   Gary Cooper, Grace Kelly, Katy Jurado, Thomas ...   western
# 944                         Audie Murphy, Faith Domergue   western
# 3859       Molly Shannon, Will Ferrell, Harland Williams    comedy
# 4443   Puneeth Rajkumar, Bhavana (Malayalam actress),...    action
# 2216            Jerry Lewis, Peter Lawford, Anne Francis    comedy
# 7232          Julie Christie, Alan Bates, Glenda Jackson     drama
# 4823   Vanidah Imran, Ramli Hassan, Bob Mercer, Zahim...     drama
# 4846                               Rajesh Khanna, Mumtaz   romance
# 4120                        Richard Widmark, Bella Darvi     drama
# 10126                      Bob Monkhouse, Ronnie Stevens    comedy
# 6009                           James Stewart, Jane Wyman     drama
# 766          Clark Gable, Sidney Poitier, Yvonne DeCarlo     drama
#
# [2500 rows x 7 columns]

# %% [markdown]
# ### Task #5: Split the data into train & test sets:
#
# Yes we have a holdout set of the data, but you do not know the genres of that data, so you can't use it to evaluate your models. Therefore you must create your own training and test sets to evaluate your models.

# %%
# Cleaning up df, creating dummy columns for all effects

effects=[]
pos=list(eff)
for p in pos:
    for i in p:
        if i not in effects:
            effects.append(i)
for i in effects:
    title=str(i)
    title=[]
    for x in df.effects:
        if i in x:
            title.append(1)
        else:
            title.append(0)
    df[i]=title
    
# Get dummies for type (indica=0,sativa=1,hybrid=2)
# Engineer features for positive effect score, negative effect score, and medical effect score

df.drop(columns='effects',inplace=True)
df.type=df.type.map({'indica':0,'sativa':1,'hybrid':2})
lowers=[]
for n in df['name']:
    lowers.append(n.lower())
df['name']=lowers
df['positive']=posi
df['negative']=neg
df['medical']=med

df.head()

# %% [markdown]
# #### Handle Class Imbalance

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE

# %%
from imblearn.over_sampling import SMOTENC

# %%
features = df1.drop(columns=['Unnamed: 0','Release Year','Title','Director','Cast','Genre'])
target = df1.Genre

# %%
features = features.to_frame()
target = target.to_frame()

# %%
smote_nc = SMOTENC(categorical_features=[0, 10], random_state=0)
X_resampled, y_resampled = smote_nc.fit_resample(features, target)
print(sorted(Counter(y_resampled).items()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-175512aef560> in <module>
#       1 smote_nc = SMOTENC(categorical_features=[0, 10], random_state=0)
# ----> 2 X_resampled, y_resampled = smote_nc.fit_resample(features, target)
#       3 print(sorted(Counter(y_resampled).items()))
#
# ~/anaconda3/lib/python3.7/site-packages/imblearn/base.py in fit_resample(self, X, y)
#      79         )
#      80
# ---> 81         output = self._fit_resample(X, y)
#      82
#      83         if self._X_columns is not None or self._y_name is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/imblearn/over_sampling/_smote.py in _fit_resample(self, X, y)
#     935     def _fit_resample(self, X, y):
#     936         self.n_features_ = X.shape[1]
# --> 937         self._validate_estimator()
#     938
#     939         # compute the median of the standard deviation of the minority class
#
# ~/anaconda3/lib/python3.7/site-packages/imblearn/over_sampling/_smote.py in _validate_estimator(self)
#     926                 raise ValueError(
#     927                     "Some of the categorical indices are out of range. Indices"
# --> 928                     " should be between 0 and {}".format(self.n_features_)
#     929                 )
#     930             self.categorical_features_ = categorical_features
#
# ValueError: Some of the categorical indices are out of range. Indices should be between 0 and 1

# %%
from sklearn.model_selection import train_test_split

X = df1['Plot']
y = df1['Genre']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### Task #6: Build a pipeline to vectorize the date, then train and fit your models.
# You should train multiple types of models and try different combinations of the tuning parameters for each model to obtain the best one. You can use the SKlearn functions of GridSearchCV and Pipeline to help automate this process.

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline

# %%
import string
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
import re

# Create our list of punctuation marks
punctuations = string.punctuation

# Create our list of stopwords
nlp = spacy.load('en_core_web_sm')
stop_words = spacy.lang.en.stop_words.STOP_WORDS

# Creating our tokenizer function
def spacy_tokenizer(text):
    # remove html tags from all of the text before processing
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', text)
    # Creating our token object, which is used to create documents with linguistic annotations.
    # we disabled the parser and ner parts of the pipeline in order to speed up parsing
    mytokens = nlp(cleantext, disable=['parser', 'ner'])

    # Lemmatizing each token and converting each token into lowercase
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]

    # Removing stop words
    mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]

    # return preprocessed list of tokens
    return mytokens

# %%
# %%capture
from tqdm import tqdm_notebook as tqdm
tqdm().pandas()

# %%
df.tail()
# Out:
#        Unnamed: 0  Release Year                          Title  \
# 10677        4652          1948                  Fighting Back
# 10678       23220          1987  The Romance of Book and Sword
# 10679       15847          2010                   Holy Rollers
# 10680        3102          1941            Lady from Louisiana
# 10681        3583          1943                Hitler's Madman
#
#                                                     Plot           Director  \
# 10677  Nick Sanders comes home from the war and needs...  Malcolm St. Clair
# 10678  The film covers the first half of the novel an...            Ann Hui
# 10679  Sam Gold (Jesse Eisenberg), is a mild-mannered...         Kevin Asch
# 10680  Yankee lawyer John Reynolds (John Wayne) and S...    Bernard Vorhaus
# 10681  Somewhat fictionalized account of the destruct...       Douglas Sirk
#
#                                                     Cast   Genre
# 10677                          Jean Rogers, Paul Langton   drama
# 10678                  Zhang Duofu, Chang Dashi, Liu Jia  action
# 10679  Jesse Eisenberg, Justin Bartha, Ari Graynor, D...   drama
# 10680                             John Wayne, Ona Munson   drama
# 10681                      Patricia Morison, Alan Curtis   drama

# %%
df1['tokenized_sents'] = df1.apply(lambda row: spacy_tokenizer(row['Plot']), axis=1)

# %%
bow_vector = CountVectorizer(tokenizer = spacy_tokenizer, ngram_range=(1,1))

# %%
tfidf_vector = TfidfVectorizer(tokenizer = spacy_tokenizers, max_features=1000, min_df=5, max_df=0.7)

# %%
def spacy_tokenizers(text):
    # remove html tags from all of the text before processing
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', text)
    # Creating our token object, which is used to create documents with linguistic annotations.
    # we disabled the parser and ner parts of the pipeline in order to speed up parsing
    mytokens = nlp(cleantext, disable=['parser', 'ner'])

#     # Lemmatizing each token and converting each token into lowercase
#     mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]

    # Removing stop words
    mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]

    # return preprocessed list of tokens
    return mytokens

# %%
X = tfidf_vector.fit_transform(df1['Plot']).toarray()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-2529f3a37f4f> in <module>
# ----> 1 X = tfidf_vector.fit_transform(df1['Plot']).toarray()
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1853         """
#    1854         self._check_params()
# -> 1855         X = super().fit_transform(raw_documents)
#    1856         self._tfidf.fit(X)
#    1857         # X is already a transformed view of raw_documents so
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1218
#    1219         vocabulary, X = self._count_vocab(raw_documents,
# -> 1220                                           self.fixed_vocabulary_)
#    1221
#    1222         if self.binary:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1129         for doc in raw_documents:
#    1130             feature_counter = {}
# -> 1131             for feature in analyze(doc):
#    1132                 try:
#    1133                     feature_idx = vocabulary[feature]
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     103             doc = preprocessor(doc)
#     104         if tokenizer is not None:
# --> 105             doc = tokenizer(doc)
#     106         if ngrams is not None:
#     107             if stop_words is not None:
#
# <ipython-input-60-f22fdfa3f283> in spacy_tokenizers(text)
#      11
#      12     # Removing stop words
# ---> 13     mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]
#      14
#      15     # return preprocessed list of tokens
#
# <ipython-input-60-f22fdfa3f283> in <listcomp>(.0)
#      11
#      12     # Removing stop words
# ---> 13     mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]
#      14
#      15     # return preprocessed list of tokens
#
# TypeError: 'in <string>' requires string as left operand, not spacy.tokens.token.Token

# %%
tfidf_vector.fit_transform(df1['tokenized_sents'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-fd91fd3435e1> in <module>
# ----> 1 tfidf_vector.fit_transform(df1['tokenized_sents'])
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1853         """
#    1854         self._check_params()
# -> 1855         X = super().fit_transform(raw_documents)
#    1856         self._tfidf.fit(X)
#    1857         # X is already a transformed view of raw_documents so
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1218
#    1219         vocabulary, X = self._count_vocab(raw_documents,
# -> 1220                                           self.fixed_vocabulary_)
#    1221
#    1222         if self.binary:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1129         for doc in raw_documents:
#    1130             feature_counter = {}
# -> 1131             for feature in analyze(doc):
#    1132                 try:
#    1133                     feature_idx = vocabulary[feature]
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     101     else:
#     102         if preprocessor is not None:
# --> 103             doc = preprocessor(doc)
#     104         if tokenizer is not None:
#     105             doc = tokenizer(doc)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _preprocess(doc, accent_function, lower)
#      66     """
#      67     if lower:
# ---> 68         doc = doc.lower()
#      69     if accent_function is not None:
#      70         doc = accent_function(doc)
#
# AttributeError: 'list' object has no attribute 'lower'

# %% [markdown]
# ### Task #7: Run predictions and analyze the results on the test set to identify the best model.

# %%
# Form a prediction set

# %%
# Report the confusion matrix

# %%
# Print a classification report

# %%
# Print the overall accuracy and F1 score

# %% [markdown]
# ### Task #8: Refit the model to all of your data and then use that model to predict the holdout set.

# %% [markdown]
# ### #9: Save your predictions as a csv file that you will send to the instructional staff for evaluation.

# %% [markdown]
# ## Great job!
